# %% [markdown]
# <!-- Autogenerated by `scripts/make_examples.py` -->
# <table align="left">
#     <td>
#         <a target="_blank" href="https://colab.research.google.com/github/voxel51/fiftyone-examples/blob/master/examples/image_deduplication.ipynb">
#             <img src="https://user-images.githubusercontent.com/25985824/104791629-6e618700-5769-11eb-857f-d176b37d2496.png" height="32" width="32">
#             Try in Google Colab
#         </a>
#     </td>
#     <td>
#         <a target="_blank" href="https://nbviewer.jupyter.org/github/voxel51/fiftyone-examples/blob/master/examples/image_deduplication.ipynb">
#             <img src="https://user-images.githubusercontent.com/25985824/104791634-6efa1d80-5769-11eb-8a4c-71d6cb53ccf0.png" height="32" width="32">
#             Share via nbviewer
#         </a>
#     </td>
#     <td>
#         <a target="_blank" href="https://github.com/voxel51/fiftyone-examples/blob/master/examples/image_deduplication.ipynb">
#             <img src="https://user-images.githubusercontent.com/25985824/104791633-6efa1d80-5769-11eb-8ee3-4b2123fe4b66.png" height="32" width="32">
#             View on GitHub
#         </a>
#     </td>
#     <td>
#         <a href="https://github.com/voxel51/fiftyone-examples/raw/master/examples/image_deduplication.ipynb" download>
#             <img src="https://user-images.githubusercontent.com/25985824/104792428-60f9cc00-576c-11eb-95a4-5709d803023a.png" height="32" width="32">
#             Download notebook
#         </a>
#     </td>
# </table>

# %% [markdown]
# # Find and remove duplicate images with FiftyOne
#
# Duplicate images in a train or test set can lead to your model learning biases that will impact its ability to generalize to new data. The problem in practice, however, is that large image datasets are difficult to examine so manually finding duplicates can be prohibitive.
#
# This notebook will guide you through how to find and remove duplicates in your data by:
#
# * Loading your data into FiftyOne
#
# * Computing embeddings for your images using the FiftyOne Model Zoo
#
# * Calculating the similarity of your images
#
# * Visualizing and automatically removing duplicates
#
# It should be noted that there are multiple ways that this can be done. The example here is useful for finding near-duplicates pairwise for every image in the dataset.
#
# [FiftyOne also provides a `uniqueness` function](https://voxel51.com/docs/fiftyone/user_guide/brain.html) that computes a scalar property over the dataset determining the uniqueness of a sample in relation to the rest of the data. It can also be used to manually find near-duplicates, with low uniqueness indicating likely duplicate or near-duplicate images. You can see an example of it at the end of the post.
#
# Alternatively, if you are only interested in exact duplicates, you can [compute a hash over your files](https://voxel51.com/docs/fiftyone/recipes/image_deduplication.html) to quickly find matches. However, if images vary by only small pixel values, this method will fail to find the duplicates.

# %% [markdown]
# ## Setup
#
# Run the following lines to install FiftyOne, Scikit Learn, and PyTorch (to generate embeddings):

# %%
# !.conda/bin/python -m pip install fiftyone
# Out:
# Requirement already satisfied: fiftyone in ./.conda/lib/python3.10/site-packages (0.24.1)
# Requirement already satisfied: aiofiles in ./.conda/lib/python3.10/site-packages (from fiftyone) (24.1.0)
# Requirement already satisfied: argcomplete in ./.conda/lib/python3.10/site-packages (from fiftyone) (3.4.0)
# Requirement already satisfied: beautifulsoup4 in ./.conda/lib/python3.10/site-packages (from fiftyone) (4.12.3)
# Requirement already satisfied: boto3 in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.34.149)
# Requirement already satisfied: cachetools in ./.conda/lib/python3.10/site-packages (from fiftyone) (5.4.0)
# Requirement already satisfied: dacite<1.8.0,>=1.6.0 in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.7.0)
# Requirement already satisfied: Deprecated in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.2.14)
# Requirement already satisfied: ftfy in ./.conda/lib/python3.10/site-packages (from fiftyone) (6.2.0)
# Requirement already satisfied: humanize in ./.conda/lib/python3.10/site-packages (from fiftyone) (4.10.0)
# Requirement already satisfied: hypercorn>=0.13.2 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.17.3)
# Requirement already satisfied: Jinja2==3.0.3 in ./.conda/lib/python3.10/site-packages (from fiftyone) (3.0.3)
# Requirement already satisfied: kaleido!=0.2.1.post1 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.2.1)
# Requirement already satisfied: matplotlib in ./.conda/lib/python3.10/site-packages (from fiftyone) (3.9.1)
# Requirement already satisfied: mongoengine==0.24.2 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.24.2)
# Requirement already satisfied: motor>=2.5 in ./.conda/lib/python3.10/site-packages (from fiftyone) (3.5.1)
# Requirement already satisfied: numpy in ./.conda/lib/python3.10/site-packages (from fiftyone) (2.0.1)
# Requirement already satisfied: packaging in ./.conda/lib/python3.10/site-packages (from fiftyone) (24.1)
# Requirement already satisfied: pandas in ./.conda/lib/python3.10/site-packages (from fiftyone) (2.2.2)
# Requirement already satisfied: Pillow>=6.2 in ./.conda/lib/python3.10/site-packages (from fiftyone) (10.4.0)
# Requirement already satisfied: plotly>=4.14 in ./.conda/lib/python3.10/site-packages (from fiftyone) (5.23.0)
# Requirement already satisfied: pprintpp in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.4.0)
# Requirement already satisfied: psutil in ./.conda/lib/python3.10/site-packages (from fiftyone) (5.9.0)
# Requirement already satisfied: pymongo>=3.12 in ./.conda/lib/python3.10/site-packages (from fiftyone) (4.8.0)
# Requirement already satisfied: pytz in ./.conda/lib/python3.10/site-packages (from fiftyone) (2024.1)
# Requirement already satisfied: PyYAML in ./.conda/lib/python3.10/site-packages (from fiftyone) (6.0.1)
# Requirement already satisfied: regex in ./.conda/lib/python3.10/site-packages (from fiftyone) (2024.7.24)
# Requirement already satisfied: retrying in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.3.4)
# Requirement already satisfied: scikit-learn in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.5.1)
# Requirement already satisfied: scikit-image in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.24.0)
# Requirement already satisfied: scipy in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.14.0)
# Requirement already satisfied: setuptools in ./.conda/lib/python3.10/site-packages (from fiftyone) (69.5.1)
# Requirement already satisfied: sseclient-py<2,>=1.7.2 in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.8.0)
# Requirement already satisfied: sse-starlette<1,>=0.10.3 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.10.3)
# Requirement already satisfied: starlette>=0.24.0 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.38.1)
# Requirement already satisfied: strawberry-graphql==0.138.1 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.138.1)
# Requirement already satisfied: tabulate in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: xmltodict in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.13.0)
# Requirement already satisfied: universal-analytics-python3<2,>=1.0.1 in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.1.1)
# Requirement already satisfied: fiftyone-brain<0.17,>=0.16.1 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.16.1)
# Requirement already satisfied: fiftyone-db<2.0,>=0.4 in ./.conda/lib/python3.10/site-packages (from fiftyone) (1.1.4)
# Requirement already satisfied: voxel51-eta<0.13,>=0.12.6 in ./.conda/lib/python3.10/site-packages (from fiftyone) (0.12.6)
# Requirement already satisfied: opencv-python-headless in ./.conda/lib/python3.10/site-packages (from fiftyone) (4.10.0.84)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.10/site-packages (from Jinja2==3.0.3->fiftyone) (2.1.5)
# Requirement already satisfied: graphql-core<3.3.0,>=3.2.0 in ./.conda/lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (3.2.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in ./.conda/lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (2.9.0)
# Requirement already satisfied: typing_extensions<5.0.0,>=3.7.4 in ./.conda/lib/python3.10/site-packages (from strawberry-graphql==0.138.1->fiftyone) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.1.0 in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.2)
# Requirement already satisfied: h11 in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (0.14.0)
# Requirement already satisfied: h2>=3.1.0 in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: priority in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.0)
# Requirement already satisfied: taskgroup in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (0.0.0a4)
# Requirement already satisfied: tomli in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (2.0.1)
# Requirement already satisfied: wsproto>=0.14.0 in ./.conda/lib/python3.10/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./.conda/lib/python3.10/site-packages (from plotly>=4.14->fiftyone) (8.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./.conda/lib/python3.10/site-packages (from pymongo>=3.12->fiftyone) (2.6.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in ./.conda/lib/python3.10/site-packages (from starlette>=0.24.0->fiftyone) (4.4.0)
# Requirement already satisfied: httpx>=0.10.0 in ./.conda/lib/python3.10/site-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.27.0)
# Requirement already satisfied: dill in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (0.3.8)
# Requirement already satisfied: future in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (1.0.0)
# Requirement already satisfied: glob2 in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (0.7)
# Requirement already satisfied: jsonlines in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (4.0.0)
# Requirement already satisfied: py7zr in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (0.21.1)
# Requirement already satisfied: rarfile in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (4.2)
# Requirement already satisfied: requests in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (2.32.3)
# Requirement already satisfied: six in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (1.16.0)
# Requirement already satisfied: sortedcontainers in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (5.2)
# Requirement already satisfied: urllib3 in ./.conda/lib/python3.10/site-packages (from voxel51-eta<0.13,>=0.12.6->fiftyone) (2.2.2)
# Requirement already satisfied: soupsieve>1.2 in ./.conda/lib/python3.10/site-packages (from beautifulsoup4->fiftyone) (2.5)
# Requirement already satisfied: botocore<1.35.0,>=1.34.149 in ./.conda/lib/python3.10/site-packages (from boto3->fiftyone) (1.34.149)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.conda/lib/python3.10/site-packages (from boto3->fiftyone) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./.conda/lib/python3.10/site-packages (from boto3->fiftyone) (0.10.2)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.conda/lib/python3.10/site-packages (from Deprecated->fiftyone) (1.16.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in ./.conda/lib/python3.10/site-packages (from ftfy->fiftyone) (0.2.13)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/lib/python3.10/site-packages (from matplotlib->fiftyone) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.conda/lib/python3.10/site-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/lib/python3.10/site-packages (from matplotlib->fiftyone) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/lib/python3.10/site-packages (from matplotlib->fiftyone) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/lib/python3.10/site-packages (from matplotlib->fiftyone) (3.1.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/lib/python3.10/site-packages (from pandas->fiftyone) (2024.1)
# Requirement already satisfied: networkx>=2.8 in ./.conda/lib/python3.10/site-packages (from scikit-image->fiftyone) (3.3)
# Requirement already satisfied: imageio>=2.33 in ./.conda/lib/python3.10/site-packages (from scikit-image->fiftyone) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.conda/lib/python3.10/site-packages (from scikit-image->fiftyone) (2024.7.24)
# Requirement already satisfied: lazy-loader>=0.4 in ./.conda/lib/python3.10/site-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn->fiftyone) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn->fiftyone) (3.5.0)
# Requirement already satisfied: idna>=2.8 in ./.conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (3.7)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in ./.conda/lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in ./.conda/lib/python3.10/site-packages (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone) (4.0.0)
# Requirement already satisfied: certifi in ./.conda/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./.conda/lib/python3.10/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.5)
# Requirement already satisfied: attrs>=19.2.0 in ./.conda/lib/python3.10/site-packages (from jsonlines->voxel51-eta<0.13,>=0.12.6->fiftyone) (23.2.0)
# Requirement already satisfied: texttable in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (3.20.0)
# Requirement already satisfied: pyzstd>=0.15.9 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (0.16.0)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in ./.conda/lib/python3.10/site-packages (from py7zr->voxel51-eta<0.13,>=0.12.6->fiftyone) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.conda/lib/python3.10/site-packages (from requests->voxel51-eta<0.13,>=0.12.6->fiftyone) (3.3.2)

# %%
# !.conda/bin/python -m pip install torch torchvision scikit-learn
# Out:
# Requirement already satisfied: torch in ./.conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: torchvision in ./.conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: scikit-learn in ./.conda/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: filelock in ./.conda/lib/python3.10/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in ./.conda/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in ./.conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.10/site-packages (from torch) (3.0.3)
# Requirement already satisfied: fsspec in ./.conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in ./.conda/lib/python3.10/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/lib/python3.10/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: scipy>=1.6.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# ## Loading your data
#
# In this example, we will be using the image classification dataset, CIFAR-100. This dataset is fairly old (2009) but still relevant enough that papers submitted to ICLR 2021 are using it as a baseline.
#
# CIFAR-100 contains 60,000 images between the train and test split annotated with 100 label classes grouped into 20 "super classes". This dataset also exists in the FiftyOne dataset zoo and can be easily loaded.

# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
# This will download all 60,000 samples
# dataset = fo.load_zoo_dataset("cifar100")
dataset = fo.Dataset.from_dir("trimmed_dataset", dataset_type=fo.types.ImageClassificationDirectoryTree)

# If you are running this notebook on a machine without a GPU or want to
# try a smaller experiment, run this version instead

# dataset = foz.load_zoo_dataset("cifar100", shuffle=True, max_samples=1000)
# Out:
#  100% |███████████████| 3287/3287 [1.6s elapsed, 0s remaining, 2.1K samples/s]

# %% [markdown]
# [Loading your own data](https://voxel51.com/docs/fiftyone/user_guide/dataset_creation/index.html) is also easy to accomplish in FiftyOne. For example, the following will let you load an image classification dataset stored in a directory tree:
#
# ```
# import fiftyone as fo
#
# dataset = fo.Dataset.from_dir("/path/to/dir", dataset_type=fo.types.ImageClassificationDirectoryTree)
# ```

# %% [markdown]
# ## Generate Embeddings
#
# Images store a lot of information in their pixel values. Comparing images pixel-by-pixel would be an expensive operation and result in poor quality results.
#
# Instead, we can use a pretrained computer vision model to generate embeddings for each image. An embedding is a result of processing an image through a model and extracting an intermediate representation of the image from within the model in the form of a vector containing a few thousand values distilling the information stored in the millions of pixels.
#
# For deep learning models, one typically uses the output of a fully-connected layer near the end of the forward pass to generate embeddings.
#
# The [FiftyOne Model Zoo](https://voxel51.com/docs/fiftyone/user_guide/model_zoo/index.html) contains a host of different pretrained models that we can use for this task. In this example, we will use a [MobileNet v2 model trained on ImageNet](https://voxel51.com/docs/fiftyone/user_guide/model_zoo/models.html#mobilenet-v2-imagenet-torch). This model provides relatively high performance, but most importantly is lightweight and can process our dataset quicker than other models.
#
# Any off-the-shelf model will be informative, but one can easily experiment with other models that may be more useful for particular datasets.
#
# We can easily load the model and compute embeddings on our dataset.

# %%
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

model = foz.load_zoo_model("mobilenet-v2-imagenet-torch")
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /Users/astronaut/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100.0%

# %%
embeddings = dataset.compute_embeddings(model)

print(embeddings.shape)
# Out:
#  100% |███████████████| 3287/3287 [3.9m elapsed, 0s remaining, 18.9 samples/s]
# (3287, 1280)

# %% [markdown]
# ## Calculate Similarity
#
# Now that we have significantly reduced the dimensionality of our images, we can use classical similarity algorithms to compute how similar every image embedding is to every other image embedding.
#
# In this case, we will use [cosine similarity provided by Scikit Learn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html) since this algorithm is simple and works fairly well in high dimensional spaces.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
similarity_matrix = cosine_similarity(embeddings)

print(similarity_matrix.shape)
print(similarity_matrix)
# Out:
# (3287, 3287)
# [[1.         0.70568911 0.72863448 ... 0.65563274 0.5298844  0.49014387]
#  [0.70568911 1.         0.71850522 ... 0.70334353 0.69492004 0.64275652]
#  [0.72863448 0.71850522 1.         ... 0.60404899 0.54432231 0.47406925]
#  ...
#  [0.65563274 0.70334353 0.60404899 ... 1.         0.68056721 0.65603726]
#  [0.5298844  0.69492004 0.54432231 ... 0.68056721 1.         0.73152648]
#  [0.49014387 0.64275652 0.47406925 ... 0.65603726 0.73152648 1.        ]]

# %% [markdown]
# As you can see, all diagonal values are 1 since every image is identical to itself. We can subtract by the identity matrix (N x N matrix with 1's on the diagonal and 0's elsewhere) in order to zero out the diagonal so those values don't show up when we look for samples with maximum similarity.

# %%
n = len(similarity_matrix)

similarity_matrix = similarity_matrix - np.identity(n)

# %% [markdown]
# **Note:** Computing cosine similarity on datasets with more than 100,000 images can time and memory intensive. It is recommended to split the embeddings into batches and parallelize the process to speed up this computation.

# %% [markdown]
# ## Visualize and remove duplicates
#
# We can now iterate through every sample and find which other samples are the most similar to it.

# %%
id_map = [s.id for s in dataset.select_fields(["id"])]

for idx, sample in enumerate(dataset):
    sample["max_similarity"] = similarity_matrix[idx].max()
    sample.save()

# %% [markdown]
# The [FiftyOne App](https://voxel51.com/docs/fiftyone/user_guide/app.html) allows us to visualize and explore our dataset right in this notebook.

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=3aa87ae4-0cd2-4646-8829-256f3d58406a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Visualizing the results and sorting by the samples with the highest similarity shows us the duplicates in the dataset.
#
# Right off the bat, we can see a lot of duplicates and something even more problematic. Two of the images are duplicates but one is in the train split and one is in the test split... and they are labeled differently (seal vs otter)!!! There are a few things wrong with this:
#
# * It can't be both a seal and an otter so one of the labels is wrong. Additionally, providing different labels for the train and test versions of the image will undoubtedly cause the model to fail.
#
# * Test sets that contain duplicates of the training set will lead to false confidence in the generalizability of your model. If your test set is not truly independent of your training set, the apparent performance of your model will likely drop-off when applied to production data.
#
# By looking through the results, we can find a threshold that we can use as a cutoff for when two images are determined to be duplicated. This threshold will be different for every dataset/model used in this process so the visualization step is crucial.

# %% [markdown]
# Further inspection puts a good threshold for guaranteed duplicates around 0.92. Lower values likely also include duplicates but should be verified manually so that we do not remove useful data. We can filter the dataset through code as well to see just how many samples have a max_similarity of > 0.92.

# %%
from fiftyone import ViewField as F

dataset.match(F("max_similarity")>0.90)
# Out:
# Dataset:     2024.07.25.17.16.39
# Media type:  image
# Num samples: 2636
# Sample fields:
#     id:             fiftyone.core.fields.ObjectIdField
#     filepath:       fiftyone.core.fields.StringField
#     tags:           fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     max_similarity: fiftyone.core.fields.FloatField
# View stages:
#     1. Match(filter={'$expr': {'$gt': [...]}})

# %% [markdown]
# 4,345 out of 60,000 samples are conservatively marked as duplicates!

# %% [markdown]
# Let's use a threshold of 0.92 and tag all duplicate samples. This is where you would remove them if so desired.

# %%
id_map = [s.id for s in dataset.select_fields(["id"])]

# %%
thresh = 0.90
samples_to_remove = set()
samples_to_keep = set()

for idx, sample in enumerate(dataset):
    if sample.id not in samples_to_remove:
        # Keep the first instance of two duplicates
        samples_to_keep.add(sample.id)

        dup_idxs = np.where(similarity_matrix[idx] > thresh)[0]
        for dup in dup_idxs:
            # We kept the first instance so remove all other duplicates
            samples_to_remove.add(id_map[dup])

        if len(dup_idxs) > 0:
            sample.tags.append("has_duplicates")
            sample.save()

    else:
        sample.tags.append("duplicate")
        sample.save()

# print(len(samples_to_remove) + len(samples_to_keep))

# If you want to remove the samples from the dataset entirely, uncomment the following line
dataset.delete_samples(list(samples_to_remove))

# %%
session.show()
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-acff132c-e77a-4f37-b2ca-4822a746b62c {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-acff132c-e77a-4f37-b2ca-4822a746b62c {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-acff132c-e77a-4f37-b2ca-4822a746b62c:focus {
#   outline: none;
# }
# #fooverlay-acff132c-e77a-4f37-b2ca-4822a746b62c {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-acff132c-e77a-4f37-b2ca-4822a746b62c">
#    <div id="fooverlay-acff132c-e77a-4f37-b2ca-4822a746b62c" style="display: none;">
#       <button id="foactivate-acff132c-e77a-4f37-b2ca-4822a746b62c" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 2864px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-acff132c-e77a-4f37-b2ca-4822a746b62c");
#      var overlay = document.getElementById("fooverlay-acff132c-e77a-4f37-b2ca-4822a746b62c");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "acff132c-e77a-4f37-b2ca-4822a746b62c" },
#               subscription: "acff132c-e77a-4f37-b2ca-4822a746b62c"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %% [markdown]
# Let's see how many of these samples have duplicates both in the test and train split and how many are labeled differently.

# %%
dataset.export(
    export_dir="./trimmed_dataset",
    dataset_type=fo.types.ImageClassificationDirectoryTree,
    label_field="ground_truth",
)
# Out:
#  100% |███████████████| 3287/3287 [2.9s elapsed, 0s remaining, 1.4K samples/s]

# %%
view = dataset.match_tags(["has_duplicates","duplicate"])
thresh = 0.92

for idx, sample in enumerate(dataset):
    if sample.id in view:
        dup_idxs = np.where(similarity_matrix[idx] > thresh)[0]
        dup_splits = []
        dup_labels = {sample.ground_truth.label}
        for dup in dup_idxs:
            dup_sample = dataset[id_map[dup]]
            dup_split = "test" if "test" in dup_sample.tags else "train"
            dup_splits.append(dup_split)
            dup_labels.add(dup_sample.ground_truth.label)

        sample["dup_splits"] = dup_splits
        sample["dup_labels"] = list(dup_labels)
        sample.save()

# %%
view.first()
# Out:
# <SampleView: {
#     'id': '60143141bc1e1009250ceb3d',
#     'media_type': 'image',
#     'filepath': '/home/erich/fiftyone/cifar100/train/data/000008.jpg',
#     'tags': BaseList(['train', 'has_duplicates']),
#     'metadata': None,
#     'ground_truth': <Classification: {
#         'id': '60143141bc1e1009250ceb3c',
#         'label': 'cup',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'max_similarity': 0.9343109560801919,
#     'dup_splits': BaseList(['train']),
#     'dup_labels': BaseList(['cup']),
# }>

# %%
from fiftyone import ViewField as F

# %% [markdown]
# Compute how many of the duplicates exist in BOTH the train and test split.

# %%
train_w_test_dups = len(
    view
    .match(F("tags").contains("train"))
    .match(F("dup_splits").contains("test"))
)

test_w_train_dups = len(
    view
    .match(F("tags").contains("test"))
    .match(F("dup_splits").contains("train"))
)

print(train_w_test_dups + test_w_train_dups)
# Out:
# 1621

# %% [markdown]
# Compute how many duplicates are labeled differently.

# %%
label_mismatches = len(
    view
    .match(F("dup_labels").length() > 1)
)

print(label_mismatches)
# Out:
# 427

# %% [markdown]
# Visualize the samples with the most number of duplicates

# %%
session.view = view.sort_by(F("dup_splits").length(), reverse=True)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-bbdd5888-d0d0-4a51-9625-5d777b79d396 {
#   position: relative;
#   display: block !important;
# }
# #foactivate-bbdd5888-d0d0-4a51-9625-5d777b79d396 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-bbdd5888-d0d0-4a51-9625-5d777b79d396:focus {
#   outline: none;
# }
# #fooverlay-bbdd5888-d0d0-4a51-9625-5d777b79d396 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-bbdd5888-d0d0-4a51-9625-5d777b79d396">
#    <div id="fooverlay-bbdd5888-d0d0-4a51-9625-5d777b79d396" style="display: none;">
#       <button id="foactivate-bbdd5888-d0d0-4a51-9625-5d777b79d396" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 967px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-bbdd5888-d0d0-4a51-9625-5d777b79d396");
#      var overlay = document.getElementById("fooverlay-bbdd5888-d0d0-4a51-9625-5d777b79d396");
#      fetch(`http://localhost:5151/notebook?handleId=bbdd5888-d0d0-4a51-9625-5d777b79d396`)
#      .then((response) => response.json())
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/reactivate?handleId=bbdd5888-d0d0-4a51-9625-5d777b79d396`)
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %% [markdown]
# ## Finding unique images
#
# FiftyOne also provides a [uniqueness method](https://voxel51.com/docs/fiftyone/user_guide/brain.html#image-uniqueness) that can compute the uniqueness of every image in a dataset. This will result in a score for every image indicating how unique the contents of the image are with respect to all other images.
#
# We previously computed near-duplicate images in the dataset with cosine similarity, but with uniqueness, we are able to rank the images in the dataset according to their relative uniqueness (i.e., information content) compared to the other images.
#
# Uniqueness can be helpful when deciding which samples to send to annotators. If you have a limited annotation budget, then you will want to have the most unique samples annotated for training and testing.

# %%
import fiftyone.brain as fob

# %%
# Process a subset of the dataset to give a taste
fob.compute_uniqueness(dataset)
# Out:
# Downloading model from Google Drive ID '1SIO9XreK0w1ja4EuhBWcR10CnWxCOsom'...
#  100% |████|  100.6Mb/100.6Mb [3.0s elapsed, 0s remaining, 33.1Mb/s]
# Computing embeddings...
#  100% |███████████████| 5832/5832 [3.1m elapsed, 0s remaining, 69.3 samples/s]
# Computing uniqueness...
# Uniqueness computation complete

# %%
uniqueness_view = dataset.exists("uniqueness").sort_by("uniqueness", reverse=True)

# %%
uniqueness_view
# Out:
# Dataset:     2024.07.25.17.16.39
# Media type:  image
# Num samples: 5832
# Sample fields:
#     id:             fiftyone.core.fields.ObjectIdField
#     filepath:       fiftyone.core.fields.StringField
#     tags:           fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth:   fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     max_similarity: fiftyone.core.fields.FloatField
#     uniqueness:     fiftyone.core.fields.FloatField
# View stages:
#     1. Exists(field='uniqueness', bool=True)
#     2. SortBy(field_or_expr='uniqueness', reverse=True, create_index=True)

# %%
session.view = uniqueness_view
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-8c4e01a0-e5b4-4c85-a617-aee401ce8513 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-8c4e01a0-e5b4-4c85-a617-aee401ce8513 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-8c4e01a0-e5b4-4c85-a617-aee401ce8513:focus {
#   outline: none;
# }
# #fooverlay-8c4e01a0-e5b4-4c85-a617-aee401ce8513 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-8c4e01a0-e5b4-4c85-a617-aee401ce8513">
#    <div id="fooverlay-8c4e01a0-e5b4-4c85-a617-aee401ce8513" style="display: none;">
#       <button id="foactivate-8c4e01a0-e5b4-4c85-a617-aee401ce8513" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 2864px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-8c4e01a0-e5b4-4c85-a617-aee401ce8513");
#      var overlay = document.getElementById("fooverlay-8c4e01a0-e5b4-4c85-a617-aee401ce8513");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "8c4e01a0-e5b4-4c85-a617-aee401ce8513" },
#               subscription: "8c4e01a0-e5b4-4c85-a617-aee401ce8513"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
session.freeze()
